# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunoLaprince/jogo-do-numero-secreto/blob/main/Atividade_Matrizes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício 1 – Criação de Matriz
# Crie uma matriz 3x5 e preencha manualmente com números inteiros.
# Depois, exiba todos os elementos na tela, um por linha.

# %%
matriz = []
for i in range(3):
    linha = []
    for j in range(5):
        valor = int(input(f"Digite o elemento [{i}][{j}]: "))
        linha.append(valor)
    matriz.append(linha)

print('Matriz final:')
for linha in matriz:
    print(linha)
# Out:
# Digite o elemento [0][0]: 1
# Digite o elemento [0][1]: 2
# Digite o elemento [0][2]: 6
# Digite o elemento [0][3]: 4
# Digite o elemento [0][4]: 3
# Digite o elemento [1][0]: 5
# Digite o elemento [1][1]: 6
# Digite o elemento [1][2]: 7
# Digite o elemento [1][3]: 9
# Digite o elemento [1][4]: 4
# Digite o elemento [2][0]: 2
# Digite o elemento [2][1]: 6
# Digite o elemento [2][2]: 1
# Digite o elemento [2][3]: 8
# Digite o elemento [2][4]: 9
# Matriz final:
# [1, 2, 6, 4, 3]
# [5, 6, 7, 9, 4]
# [2, 6, 1, 8, 9]

# %% [markdown]
# Exercício 2 – Acesso e Impressão de Elementos
# Com a matriz criada no exercício anterior, exiba:
#
# o primeiro elemento da primeira linha;
#
# o último elemento da segunda linha.

# %%
print(matriz[0][0])
print(matriz[1][4])
# Out:
# 1
# 4

# %% [markdown]
# Exercício 3 – Matriz com Entrada do Usuário, Crie um programa que:
#
# 1.Peça ao usuário os valores para preencher uma matriz 3x2 (3 linhas e 2 colunas);
#
# 2.Ao final, exiba a matriz formatada linha por linha.

# %%
matriz = [] # criou um vertor vazio
line = int(input('Digite o número de linhas da matriz: '))
column = int(input('Digite o número de colunas da matriz: '))

for i in range(line):
    linha = []
    for j in range(column):
        valor = int(input(f"Digite o elemento [{i}][{j}]: "))
        linha.append(valor)
    matriz.append(linha)

print('Matriz final:')
for linha in matriz:
  print(linha)
# Out:
# Digite o número de linhas da matriz: 3
# Digite o número de colunas da matriz: 2
# Digite o elemento [0][0]: 1
# Digite o elemento [0][1]: 2
# Digite o elemento [1][0]: 3
# Digite o elemento [1][1]: 4
# Digite o elemento [2][0]: 5
# Digite o elemento [2][1]: 6
# Matriz final:
# [1, 2]
# [3, 4]
# [5, 6]

# %% [markdown]
# Exercício 4 – Soma de Todos os Elementos. Crie uma matriz 3x3 com valores definidos pelo usuário e calcule:
#
# A soma total de todos os elementos da matriz;
#
# Exiba o resultado final.

# %%
matriz = [] # criou um vertor vazio
soma = 0
line = int(input('Digite o número de linhas da matriz: '))
column = int(input('Digite o número de colunas da matriz: '))

for linha in matriz:
    for valor in linha:
        soma += valor
print('Soma dos valores:', soma)

# Calculando a soma de todos os elementos da matriz
print('Matriz final:')
for linha in matriz:
  print(linha)
  print('Soma de todos os elementos é:' , soma)
# Out:
# Digite o número de linhas da matriz: 3
# Digite o número de colunas da matriz: 3
# Soma dos valores: 0
# Matriz final:

# %%
import random
matriz = []
soma = 0
line = int(input('Digite o número de linhas da matriz: '))
column = int(input('Digite o número de colunas da matriz: '))

for i in range(line):
    linha = []
    for j in range(column):
        linha.append(random.randint(1, 101))
    matriz.append(linha)

print('\n Matriz final:')
for linha in matriz:
  print(linha)

  for linha in matriz:
    soma += valor
print('\nSoma dos valores:', soma)
# Out:
# Digite o número de linhas da matriz: 3
# Digite o número de colunas da matriz: 3
#
#  Matriz final:
# [84, 15, 78]
# [41, 62, 65]
# [49, 88, 39]
#
# Soma dos valores: 252

# %% [markdown]
# Exercício 5 – Soma de Duas Matrizes. Crie duas matrizes 4x4 e gere uma terceira matriz contendo a soma dos valores
# correspondentes.

# %%
import random
matriz1 = []
matriz2 = []
matrizsoma = []
soma = 0
line = int(input('Digite o número de linhas da matriz: '))
column = int(input('Digite o número de colunas da matriz: '))

for i in range(line):
    linha = []
    for j in range(column):
        linha.append(random.randint(1, 101))
    matriz1.append(linha)

for i in range(line):
    linha = []
    for j in range(column):
        linha.append(random.randint(1, 101))
    matriz2.append(linha)

for i in range(line):
    linha = []
    for j in range(column):
        soma = matriz1[i][j] + matriz2[i][j]
        linha.append(soma)
    matrizsoma.append(linha)

print('\n')
for line in matriz1:
    print(line)

print('\n')
for line in matriz2:
    print(line)

print('\n')
for line in matrizsoma:
    print(line)
# Out:
# Digite o número de linhas da matriz: 4
# Digite o número de colunas da matriz: 4
#
#
# [31, 1, 38, 60]
# [22, 78, 42, 88]
# [17, 57, 14, 22]
# [21, 101, 65, 50]
#
#
# [53, 51, 4, 8]
# [63, 82, 25, 33]
# [51, 79, 1, 82]
# [10, 69, 34, 30]
#
#
# [84, 52, 42, 68]
# [85, 160, 67, 121]
# [68, 136, 15, 104]
# [31, 170, 99, 80]

# %% [markdown]
# Exercício 6 – Média e Elementos Maiores que a Média
#
# Crie uma matriz 2x3 com valores definidos pelo usuário;
#
# Calcule a média de todos os elementos;
#
# Mostre quais números são maiores que a média.

# %%
import random
contador1 = []
contador2 = []
matriz1 = []
matriz2 = []
mediamatriz = []

soma = 0
line = int(input('Digite o número de linhas da matriz: '))
column = int(input('Digite o número de colunas da matriz: '))

for i in range(line):
    linha = []
    for j in range(column):
        linha.append(random.randint(1, 101))
    matriz1.append(linha)

for i in range(line):
    linha = []
    for j in range(column):
        linha.append(random.randint(1, 101))
    matriz2.append(linha)

for i in range(line):
    linha = []
    for j in range(column):
        media = soma(matriz1[i][j]) / soma(matriz2[i][j])
        linha.append(media)
    mediamatriz.append(linha)

print('\n')
for line in matriz1:
    print(line)

print('\n')
for line in matriz2:
    print(line)

print('\n')
for line in mediamatriz:
    print(line)
# Out:
# Digite o número de linhas da matriz: 2
# Digite o número de colunas da matriz: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2174002658.py in <cell line: 0>()
#      25     linha = []
#      26     for j in range(column):
# ---> 27         media = soma(matriz1[i][j]) / soma(matriz2[i][j])
#      28         linha.append(media)
#      29     mediamatriz.append(linha)
#
# TypeError: 'int' object is not callable

# %%
import random
line = int(input('Digite o número de linhas da matriz: '))
column = int(input('Digite o número de colunas da matriz: '))

#Criação da matriz 2x3 com valores aleatórios
matriz = []
for i in range (line):
    line = []
    for j in range (column):
        valor = random.randint(1, 101)
        line.append(valor)
    matriz.append(line)

# Calculando a média de todos os elementos
soma_total = 0
qtd = 0
for linha in matriz:
    for valor in linha:
        soma_total += valor
        qtd += 1
media = soma_total / qtd

#Identificando os elementos maiores que a média
maiores = []
for linha in matriz:
    for valor in linha:
        if valor > media:
            maiores.append(valor)

print('Matriz gerada aleatoriamente:')
for linha in matriz:
    print(linha)

print(f'\nMédia dos elementos: {media}')

if maiores:
    print('Elementos maiores que a média:', maiores)
else:
    print('Não há elementos maiores que a média na matriz.')
# Out:
# Digite o número de linhas da matriz: 3
# Digite o número de colunas da matriz: 3
# Matriz gerada aleatoriamente:
# [22, 91, 91]
# [81, 97, 86]
# [55, 58, 21]
#
# Média dos elementos: 66.88888888888889
# Elementos maiores que a média: [91, 91, 81, 97, 86]

# %% [markdown]
# Desafio Final – Diagonal e Soma dos Pares. Crie um programa que:
#
# - Solicite os valores para uma matriz 3x3;
#
# - Mostre a soma dos valores da diagonal principal;
# Mostre também a soma dos valores pares da matriz.
#
# Dica:
# A diagonal principal ocorre quando linha == coluna;
# Um número é par se valor % 2 == 0.

# %%
# Definindo a matriz
matriz = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Soma da diagonal principal
soma_diagonal_principal = sum(matriz[i][i] for i in range(len(matriz)))

# Soma dos valores pares
soma_pares = sum(valor for linha in matriz for valor in linha if valor % 2 == 0)

# Exibindo os resultados
print(f"Soma da diagonal principal: {soma_diagonal_principal}")
print(f"Soma dos valores pares: {soma_pares}")
# Out:
# Soma da diagonal principal: 15
# Soma dos valores pares: 20

# %%
import random
matriz1 = []
matriz2 = []
soma_pares = 0
soma_diagonal = 0

line = int(input('Digite o número de linhas da matriz: '))
column = int(input('Digite o número de colunas da matriz: '))

for i in range(line):
    linha = []
    for j in range(column):
        linha.append(random.randint(1, 101))
    matriz1.append(linha)

for i in range(line):
    linha = []
    for j in range(column):
        linha.append(random.randint(1, 101))
    matriz2.append(linha)

for i in range(line):
    linha = []
    for j in range(column):
        if i == j:
          soma_diagonal += valor
        if valor % 2 == 0:
                soma_pares += valor
    matriz.append(linha)


print('\n')
for line in matriz1:
    print(line)

print('\n')
for line in matriz2:
    print(line)

print('\n')
for linha in matriz:
    print(f'Soma da diagonal principal:, {soma_diagonal}')
# Out:
# Digite o número de linhas da matriz: 3
# Digite o número de colunas da matriz: 3
#
#
# [5, 90, 100]
# [101, 95, 47]
# [35, 44, 30]
#
#
# [42, 63, 22]
# [30, 94, 33]
# [5, 34, 32]
#
#
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# Soma da diagonal principal:, 27
# ...

# %%
matriz = []
soma_diagonal = 0
soma_pares = 0

for i in range(3):
    linha = []
    for j in range(3):
        valor = int(input(f"Digite o elemento [{i}][{j}]: "))
        linha.append(valor)
        if i == j:
            soma_diagonal += valor
        if valor % 2 == 0:
            soma_pares += valor
    matriz.append(linha)

print('Matriz final:')
for linha in matriz:
    print(linha)

print(f'Soma da diagonal principal: {soma_diagonal}')
print(f'Soma dos pares: {soma_pares}')
# Out:
# Digite o elemento [0][0]: 1
# Digite o elemento [0][1]: 2
# Digite o elemento [0][2]: 3
# Digite o elemento [1][0]: 4
# Digite o elemento [1][1]: 5
# Digite o elemento [1][2]: 6
# Digite o elemento [2][0]: 7
# Digite o elemento [2][1]: 8
# Digite o elemento [2][2]: 9
# Matriz final:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
# Soma da diagonal principal: 15
# Soma dos pares2: 20
